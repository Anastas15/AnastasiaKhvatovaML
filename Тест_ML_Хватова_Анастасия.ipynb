# %%
'''
Введение в машинное обучение:
   1. Какие из перечисленных пунктов являются основными компонентами машинного обучения?
    +1) Оптимизация
     2) Классификация
     3) Обучение без учителя
    +4) Регрессия
    +5) Кластеризация

   2. Что такое машинное обучение?
    +1) Численная оптимизация параметрических моделей для описания определённого набора данных
     2) Метод для создания искусственного интеллекта
     3) Алгоритм для оптимизации данных
     4) Технология для кластеризации информации
     5) Процесс создания компьютерных программ

Регрессия как задача машинного обучения:
   3.  Что представляет собой задача регрессии в машинном обучении?
    +1) Предсказание числовых значений на основе входных данных
     2) Классификация данных по категориям
     3) Определение выбросов в данных
     4) Анализ временных рядов
     5) Кластеризация больших объемов информации

   4. Какие методы могут использоваться для решения задачи регрессии?
    +1) Линейная регрессия
    +2) Логистическая регрессия
    +3) Деревья принятия решений
     4) Метод опорных векторов
     5) Нейронные сети

 Линейная регрессия:
   5. Что описывает модель линейной регрессии?
    +1) Взаимосвязь между зависимой переменной и одной или несколькими независимыми переменными
     2) Предсказание категориальных значений на основе входных данных
     3) Анализ временных рядов
     4) Кластеризация данных по группам
     5) Определение выбросов в данных

   6. Как можно оценить качество модели линейной регрессии?
    +1) Среднеквадратичная ошибка
    +2) R-квадрат
     3) Коэффициент детерминации
     4) Кросс-валидация
     5) F-тест

 Множественная регрессия:
   7.  Какие переменные используются в множественной регрессии?
     1) Зависимые переменные
     2) Независимые переменные
     3) Контрольные переменные
     4) Взаимодействующие переменные
    +5) Всё вышеперечисленное

Задача классификации:
   8. Какие методы используются для задачи классификации?
    +1) Метод k-ближайших соседей
     2) Логистическая регрессия
    +3) Деревья принятия решений
    +4) Метод опорных векторов
     5) Градиентный спуск

   9. Какие метрики используются для оценки качества модели классификации?
    +1) Точность
    +2) Полнота
    +3) F1-мера
    +4) AUC-ROC
     5) R-квадрат

 Логистическая регрессия:
   10. Какие методы используются для обучения модели логистической регрессии?
    +1) Градиентный спуск
    +2) Метод Ньютона-Рафсона
     3) Метод опорных векторов
     4) Метод главных компонент
     5) Метод случайного леса

 Полиномиальные модели:
   11. Какие методы используются для создания полиномиальных моделей?
    +1) Линейная регрессия
     2) Метод опорных векторов
     3) Деревья принятия решений
    +4) Полиномиальная регрессия
     5) Градиентный спуск

   12. Какие преобразования данных могут использоваться для создания полиномиальных моделей?
    +1) Возведение в квадрат
    +2) Умножение признаков друг на друга
     3) Преобразование категориальных переменных в числовые
     4) Применение логарифмической функции к данным
     5) Применение стандартизации к данным

 Полиномиальная регрессия:
   13. Что представляет собой полиномиальная регрессия?
     1) Линейную зависимость между зависимой и независимыми переменными
    +2) Нелинейную зависимость между зависимой и независимыми переменными
     3) Множественную зависимость между несколькими независимыми переменными
     4) Логистическую зависимость между двумя категориальными переменными
     5) Линейную зависимость между несколькими зависимыми переменными

   14. Какие метрики используются для оценки качества полиномиальной регрессии?
    +1) R-квадрат
    +2) Средняя абсолютная ошибка
    +3) Среднеквадратичная ошибка
     4) Коэффициент детерминации
     5) F-тест
'''
